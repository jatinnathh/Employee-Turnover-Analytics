# %% [markdown]
# # Report on Employee Turnover Project

# %% [markdown]
# 1. As it can be seen in the heat map , the correlation between **'Left'** and **' Satisfaction_level'** is lowest negative indicationg that people leaving are not very satisfied and the correlation between **'average_monthly_hours'** and **'number_projects'** is the highest positive

# %% [markdown]
# ![heat.png](attachment:c9406cf8-b0cc-4355-ae9a-b13a09c52d5f.png)

# %% [markdown]
# 2. the average satisfaction level of all employees is 0.75 with the frequency 1250

# %% [markdown]
# ![satisfaction_distri.png](attachment:584bb3a5-50d8-4f6f-b738-22a41ce0816c.png)

# %% [markdown]
# 3. the average monthly hours of all employees is 0.75 with the frequency 1250

# %% [markdown]
# ![average_hours.png](attachment:d722183e-a0a2-4c7a-a24d-b372efd62a7a.png)

# %% [markdown]
# 4. Project count of employees who left v.s those who stayed.
# It can be seen that employees who actually stayed had done more projects than those who stayed

# %% [markdown]
# ![project_count.png](attachment:454d8df8-26cf-418d-8602-00fcee978ea2.png)

# %% [markdown]
# 5. Clustering

# %% [markdown]
# ![clustering_k_means.png](attachment:3f49f2f2-0df4-4f5f-85c5-2b50af13ae7e.png)

# %% [markdown]
# It can be seen that more employees with high last evaluation had high satisfaction level working for the company whereas some of those differed from the assumption .

# %% [markdown]
# 6. **ROC AND AUC**

# %% [markdown]
# ![AUC.png](attachment:34220884-b396-4378-aa1d-5492b3b0bdf2.png)

# %% [markdown]
# It can be seen that **Random Forest** performs the best among all the models as it is having the maximum area under the curve

# %% [markdown]
# 7. **Confusion matrices**

# %% [markdown]
# * *logistic regression confusion matrix below:*

# %% [markdown]
# ![log_confusion.png](attachment:5d77f2af-381c-4d5d-bd22-9072098a44ec.png)

# %% [markdown]
# * *Random Forest confusion matrix below:*

# %% [markdown]
# ![random_confusion.png](attachment:bf9180eb-9d61-40e2-a77c-24ffc1374044.png)

# %% [markdown]
# * *Gradient boosting confusion matrix below:*

# %% [markdown]
# ![Gradient_confusion.png](attachment:a46e2f55-4c42-443a-9d79-05c68ed2bdad.png)

# %% [markdown]
# As we can see , **Random Forest** has the lowest False Positive Rate and lowest True Negative Rate

# %% [markdown]
# 8. The four zones of employees with
# * Safe Zone (Green) (Score < 20%)
# * Low-Risk Zone (Yellow) (20% < Score < 60%)
# * Medium-Risk Zone (Orange) (60% < Score < 90%)
# * High-Risk Zone (Red) (Score > 90%).

# %% [markdown]
# ![Piechart.png](attachment:923384d6-adf8-4cac-b31f-51c86a4f9ac9.png)
